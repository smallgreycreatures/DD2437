# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import regularizers
from keras import backend
# Out:
# Using TensorFlow backend.

# %%
def _x(t,data):
    return 0 if t < 0 else data[t]

def x(t,data):
    beta = 0.2
    gamma = 0.1
    tau = 25
    n = 10
    return _x(t-1,data) + (beta*_x(t-tau-1,data))/(1+_x(t-tau-1,data)**n) - gamma*_x(t-1,data)

def mackey_glass_generator():


    N = 2000

    data = np.zeros(N)
    data[0] = 1.5

    for t in range(1,N):
        data[t] = x(t,data)

    return data
def get_train_test_data(x):
    train_set = np.zeros([1000,5])
    train_labels = np.zeros([1000])
    
    for t in range(300,1300):
        train_set[t-300,:] = [x[t-20], x[t-15], x[t-10], x[t-5], x[t]]
        train_labels[t-300] = x[t+5] 

    test_set = np.zeros([200,5])
    test_labels = np.zeros([200])
    
    for t in range(1300,1500):
        test_set[t-1300,:] = [x[t-20], x[t-15], x[t-10], x[t-5], x[t]]
        test_labels[t-1300] = x[t+5] 
        
    return train_set, train_labels, test_set, test_labels

def init_network(num_nodes, lambd):
    if len(num_nodes) < 1:
        return None

    model = Sequential()

    num_layers = len(num_nodes)
    model.add(Dense(num_nodes[0], input_dim=5, kernel_initializer='normal', activation='relu',use_bias=True, activity_regularizer=regularizers.l2(lambd)))
    for i in range(1, num_layers):
        model.add(Dense(num_nodes[i], kernel_initializer='normal', activation='relu', use_bias=True, activity_regularizer=regularizers.l2(lambd)))
    model.add(Dense(1, kernel_initializer='normal', activation='relu', use_bias=True, activity_regularizer=regularizers.l2(lambd)))
    #not sparse data so we use L2 reg
    model.summary()
    sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='mse',metrics=['MSE'])
    es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, min_delta=0.001, patience=100)
    return model, es

# %%
x = mackey_glass_generator()
print(len(x))
t = np.arange(len(x))
plt_A, = plt.plot(t,x, label='Mackey time series')
plt.legend(handles=[plt_A])
plt.show()
# Out:
# 2000

# %%
def error_mse(T, Y):
    #return np.sum((T - Y) ** 2) / 2
    return np.mean(((Y-T)**2))

train_set, train_labels, test_set, test_labels = get_train_test_data(x)
nodes_first_layer = [2,4,6,8]

lamb = 0.0
lamb = 1e-4
rounds = 10
MSE_test_round = np.zeros((len(nodes_first_layer),rounds))
for i in range(rounds):
    MSE_test = np.zeros(len(nodes_first_layer))
    for k in range(len(nodes_first_layer)):
        print("Nodes hidden layer: ", nodes_first_layer[k])

        #if hidden_nodes_first_layer[j] > hidden_nodes_second_layer[i]:
        model, early_stopping = init_network([nodes_first_layer[k]],lamb)
        history = model.fit(train_set, train_labels, epochs=10000, batch_size=50, validation_split=0.2,  callbacks=[early_stopping], verbose=0)

        predictions = model.predict(test_set, verbose=0)
        print("MSE training:",history.history['MSE'][-1])
        print("MSE val:",history.history['val_MSE'][-1])
        test_mse = error_mse(test_labels,predictions)
        MSE_test[k] = test_mse
        print("MSE test: ", test_mse)
        """
        fig = plt.figure(figsize=(12,12))
        ax1 = fig.add_subplot(311)
        ax2 = fig.add_subplot(312)
        ax3 = fig.add_subplot(313)

        # Plot training & validation accuracy valuesa
        ax1.plot(history.history['MSE'])
        ax1.plot(history.history['val_MSE'])
        ax1.set_title('Mean squared error, nPerceptrons='+str(nodes_first_layer[k]))
        ax1.set_ylabel('MSE')
        ax1.set_xlabel('Epoch')
        ax1.legend(['Train', 'Test'], loc='upper left')

        # Plot training & validation loss values
        ax2.plot(history.history['loss'])
        ax2.plot(history.history['val_loss'])
        ax2.set_title('Model loss, nPerceptrons='+str(nodes_first_layer[k]))
        ax2.set_ylabel('Loss')
        ax2.set_xlabel('Epoch')
        ax2.legend(['Train', 'Test'], loc='upper left')

        keras.backend.clear_session()
        t = np.arange(301,len(x)-500)

        ax3.plot(t,x[301:len(x)-500])
        ax3.plot(range(1300,1500),predictions,'ro',markersize=2)
        ax3.set_xlabel("time step")
        ax3.set_ylabel("x")
        ax3.set_title("Mackey-Glass Time Series (x(0) = 1.5)")
        ax3.set_xlim([1200,1500])
        
        plt.show()
        """
    MSE_test_round[:,i] = MSE_test
# Out:
# Nodes hidden layer:  2
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 2)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 00101: early stopping
# MSE training: 0.8934375
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 24
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00330: early stopping
# MSE training: 0.001529959
# MSE val: 0.0012819776311516762
# MSE test:  0.19130008980114352
# Nodes hidden layer:  6
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 6)                 36
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00223: early stopping
# MSE training: 0.009390462
# MSE val: 0.008820955641567707
# MSE test:  0.18325048555983267
# Nodes hidden layer:  8
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 8)                 48
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00323: early stopping
# MSE training: 0.0017237605
# MSE val: 0.0015813937643542886
# MSE test:  0.19127993941991567
# Nodes hidden layer:  2
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 2)                 12
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.89343745
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00287: early stopping
# MSE training: 0.009474581
# MSE val: 0.008567029610276222
# MSE test:  0.18262336481582733
# Nodes hidden layer:  6
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00276: early stopping
# MSE training: 0.009265489
# MSE val: 0.008662926964461803
# MSE test:  0.18167294528253577
# Nodes hidden layer:  8
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00301: early stopping
# MSE training: 0.0015196764
# MSE val: 0.0012319469824433327
# MSE test:  0.19096911946302347
# Nodes hidden layer:  2
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00234: early stopping
# MSE training: 0.009343241
# MSE val: 0.008643383160233498
# MSE test:  0.18175647700799108
# Nodes hidden layer:  4
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00391: early stopping
# MSE training: 0.0017353918
# MSE val: 0.0016480773920193315
# MSE test:  0.18810955785071343
# Nodes hidden layer:  6
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00357: early stopping
# MSE training: 0.0014913299
# MSE val: 0.0012254250468686223
# MSE test:  0.1915946992967201
# Nodes hidden layer:  8
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00185: early stopping
# MSE training: 0.010025488
# MSE val: 0.009360062889754772
# MSE test:  0.18056153302903902
# Nodes hidden layer:  2
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.8934375
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00339: early stopping
# MSE training: 0.0015172471
# MSE val: 0.0013328349450603127
# MSE test:  0.19111897689008345
# Nodes hidden layer:  6
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00236: early stopping
# MSE training: 0.009296632
# MSE val: 0.008888501673936844
# MSE test:  0.18107174713038543
# Nodes hidden layer:  8
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00292: early stopping
# MSE training: 0.009210717
# MSE val: 0.009286980144679546
# MSE test:  0.18076599574477187
# Nodes hidden layer:  2
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.8934375
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00293: early stopping
# MSE training: 0.009369928
# MSE val: 0.008504413068294525
# MSE test:  0.18247569489086793
# Nodes hidden layer:  6
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.89343756
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  8
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00223: early stopping
# MSE training: 0.009374325
# MSE val: 0.008759113028645515
# MSE test:  0.18169090288858025
# Nodes hidden layer:  2
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_42 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.89343756
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00274: early stopping
# MSE training: 0.0016983137
# MSE val: 0.0013975289184600115
# MSE test:  0.19099790294859484
# Nodes hidden layer:  6
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00212: early stopping
# MSE training: 0.009386156
# MSE val: 0.008898631669580936
# MSE test:  0.1807297294659606
# Nodes hidden layer:  8
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_47 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00271: early stopping
# MSE training: 0.009302905
# MSE val: 0.00873590912669897
# MSE test:  0.18162089208203827
# Nodes hidden layer:  2
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.89343745
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  4
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_52 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00224: early stopping
# MSE training: 0.009363589
# MSE val: 0.008869998157024384
# MSE test:  0.1813449699326748
# Nodes hidden layer:  6
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_54 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00229: early stopping
# MSE training: 0.009274305
# MSE val: 0.00903414748609066
# MSE test:  0.1805618857384971
# Nodes hidden layer:  8
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_55 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_56 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00282: early stopping
# MSE training: 0.0016911103
# MSE val: 0.0014284539502114058
# MSE test:  0.1907129426235315
# Nodes hidden layer:  2
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_57 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00287: early stopping
# MSE training: 0.0017346244
# MSE val: 0.001479710335843265
# MSE test:  0.19047755567712032
# Nodes hidden layer:  4
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_59 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_60 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00253: early stopping
# MSE training: 0.00877926
# MSE val: 0.008443725295364857
# MSE test:  0.18151346848580832
# Nodes hidden layer:  6
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_62 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.8934375
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  8
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_63 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_64 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00310: early stopping
# MSE training: 0.0016401778
# MSE val: 0.0014720768667757511
# MSE test:  0.19201315044098483
# Nodes hidden layer:  2
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_65 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_66 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00268: early stopping
# MSE training: 0.009296976
# MSE val: 0.008698179386556149
# MSE test:  0.18117735938610668
# Nodes hidden layer:  4
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_67 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_68 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00208: early stopping
# MSE training: 0.009489337
# MSE val: 0.00870143249630928
# MSE test:  0.18204874373832292
# Nodes hidden layer:  6
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_69 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_70 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00341: early stopping
# MSE training: 0.0014447912
# MSE val: 0.0011753890430554748
# MSE test:  0.19162398059226352
# Nodes hidden layer:  8
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_71 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00101: early stopping
# MSE training: 0.8934375
# MSE val: 0.907838761806488
# MSE test:  0.8409943688864523
# Nodes hidden layer:  2
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_73 (Dense)             (None, 2)                 12
# _________________________________________________________________
# dense_74 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00172: early stopping
# MSE training: 0.0105521055
# MSE val: 0.009768215008080006
# MSE test:  0.17857902408016652
# Nodes hidden layer:  4
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_75 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_76 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00284: early stopping
# MSE training: 0.008906177
# MSE val: 0.008356044068932533
# MSE test:  0.18204613082333926
# Nodes hidden layer:  6
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_77 (Dense)             (None, 6)                 36
# _________________________________________________________________
# dense_78 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00508: early stopping
# MSE training: 0.0017932691
# MSE val: 0.0018413093639537692
# MSE test:  0.18780167980899487
# Nodes hidden layer:  8
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_79 (Dense)             (None, 8)                 48
# _________________________________________________________________
# dense_80 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00257: early stopping
# MSE training: 0.0017478422
# MSE val: 0.0014036637730896473
# MSE test:  0.19034439479610044

# %%
med = np.median(MSE_test_round, axis=1)
plt.plot([2,4,6,8],med)
plt.ylabel('Median MSE')
plt.xlabel('Epoch')
print(med)
# Out:
# [0.84099437 0.18254953 0.18552608 0.19052867]

# %% [raw]
# Ju fler noder desto fler epoker innan early stop. MSE för test är minst med 8 noder men det varierar.

# %%
nPerceptron = 8
lamb = 1e-4
model, early_stopping = init_network([nPerceptron],1e-4)

history = model.fit(train_set, train_labels, epochs=10000, batch_size=50, validation_split=0.2,  callbacks=[early_stopping], verbose=0)

predictions = model.predict(test_set, verbose=0)

print("MSE training:",history.history['MSE'][-1])
print("MSE val:",history.history['val_MSE'][-1])

fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(111)

t = np.arange(301,len(x)-500)

ax1.plot(t,x[301:len(x)-500])
ax1.plot(range(1300,1500),predictions,'ro',markersize=2)
ax1.set_xlabel("time step")
ax1.set_ylabel("x")
ax1.set_title("Mackey-Glass Time Series (x(0) = 1.5)")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 48
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00336: early stopping
# MSE training: 0.0014718014
# MSE val: 0.0012011940125375986
# Text(0.5, 1.0, 'Mackey-Glass Time Series (x(0) = 1.5)')

# %%
weights, biases = model.layers[0].get_weights()
plt.hist(weights)
plt.xlabel("weight value")
plt.ylabel("number of weights")
plt.title("Weight distribution for 8 nodes, lambda = 0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     299         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 300             fetch, allow_tensor=True, allow_operation=True))
#     301       except TypeError as e:
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    3477     with self._lock:
# -> 3478       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    3479
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3556       if obj.graph is not self:
# -> 3557         raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3558       return obj
#
# ValueError: Tensor Tensor("dense_1/kernel/Read/ReadVariableOp:0", shape=(5, 8), dtype=float32) is not an element of this graph.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8a2302164d24> in <module>
# ----> 1 weights, biases = model.layers[0].get_weights()
#       2 plt.hist(weights)
#       3 plt.xlabel("weight value")
#       4 plt.ylabel("number of weights")
#       5 plt.title("Weight distribution for 8 nodes, lambda = 0")
#
# /usr/local/lib/python3.7/site-packages/keras/engine/base_layer.py in get_weights(self)
#    1136         """
#    1137         params = self.weights
# -> 1138         return K.batch_get_value(params)
#    1139
#    1140     def get_config(self):
#
# /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2937         A list of Numpy arrays.
#    2938     """
# -> 2939     return tf_keras_backend.batch_get_value(ops)
#    2940
#    2941
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in batch_get_value(tensors)
#    2817     raise RuntimeError('Cannot get value inside Tensorflow graph function.')
#    2818   if tensors:
# -> 2819     return get_session().run(tensors)
#    2820   else:
#    2821     return []
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     # Create a fetch handler to take care of the structure of fetches.
#    1136     fetch_handler = _FetchHandler(
# -> 1137         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1138
#    1139     # Run request and get response.
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     469     """
#     470     with graph.as_default():
# --> 471       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     472     self._fetches = []
#     473     self._targets = []
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in for_fetch(fetch)
#     259     elif isinstance(fetch, (list, tuple)):
#     260       # NOTE(touts): This is also the code path for namedtuples.
# --> 261       return _ListFetchMapper(fetch)
#     262     elif isinstance(fetch, collections.Mapping):
#     263       return _DictFetchMapper(fetch)
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in __init__(self, fetches)
#     368     """
#     369     self._fetch_type = type(fetches)
# --> 370     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     371     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     372
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in <listcomp>(.0)
#     368     """
#     369     self._fetch_type = type(fetches)
# --> 370     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     371     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     372
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in for_fetch(fetch)
#     269         if isinstance(fetch, tensor_type):
#     270           fetches, contraction_fn = fetch_fn(fetch)
# --> 271           return _ElementFetchMapper(fetches, contraction_fn)
#     272     # Did not find anything.
#     273     raise TypeError('Fetch argument %r has invalid type %r' % (fetch,
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     305       except ValueError as e:
#     306         raise ValueError('Fetch argument %r cannot be interpreted as a '
# --> 307                          'Tensor. (%s)' % (fetch, str(e)))
#     308       except KeyError as e:
#     309         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# ValueError: Fetch argument <tf.Variable 'dense_1/kernel:0' shape=(5, 8) dtype=float32> cannot be interpreted as a Tensor. (Tensor Tensor("dense_1/kernel/Read/ReadVariableOp:0", shape=(5, 8), dtype=float32) is not an element of this graph.)
