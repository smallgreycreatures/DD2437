# %%
import numpy as np
import itertools
import matplotlib.pyplot as plt

# %%
results = np.array([1.53173737,1.457608,1.41014272,1.38035068])
plt.plot(100*np.arange(2,6),results)
plt.ylabel("Reconstuction loss")
plt.xlabel("Number of nodes")
# Out:
# Text(0.5, 0, 'Number of nodes')
